# %%
from get_data import *

# %%
agg_trade_plot("BTCUSDT","10 days ago UTC")

# %%
kline_plot("ETHUSDT", Client.KLINE_INTERVAL_1HOUR, "1 Jan, 2019")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-23dd7088e465> in <module>
# ----> 1 kline_plot("ETHUSDT", Client.KLINE_INTERVAL_1HOUR, "1 Jan, 2019")
#
# c:\Users\James\OneDrive\Documents\git\stocks-model\get_data.py in kline_plot(symbol, interval, start_date, end_date)
#      41
#      42     df = pd.DataFrame(data, columns=column_names)
# ---> 43     df["Date"] = pd.to_datetime(df["Open time"], unit='ms').dt.datetime
#      44     print(df)
#      45     fig = go.Figure(data=[go.Candlestick(
#
# AttributeError: 'DatetimeProperties' object has no attribute 'datetime'
