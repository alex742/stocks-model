# %%
from get_data import *
# Out:
# 1546214400.0
# 1547078400.0
# 864000.0
# []
# []

# %%
kline_plot("BTCUSDT", Client.KLINE_INTERVAL_1HOUR, "30 Dec, 2018")
# Out:
# Open time           Open           High            Low  \
# 0      1546214400000  3803.12000000  3810.00000000  3786.02000000
# 1      1546218000000  3795.38000000  3797.46000000  3745.59000000
# 2      1546221600000  3762.65000000  3767.60000000  3715.73000000
# 3      1546225200000  3727.93000000  3751.58000000  3725.48000000
# 4      1546228800000  3744.59000000  3756.06000000  3731.76000000
# ...              ...            ...            ...            ...
# 12570  1591599600000  9731.89000000  9743.49000000  9715.00000000
# 12571  1591603200000  9727.51000000  9738.57000000  9633.00000000
# 12572  1591606800000  9689.99000000  9800.00000000  9685.03000000
# 12573  1591610400000  9745.86000000  9754.58000000  9727.04000000
# 12574  1591614000000  9737.22000000  9744.63000000  9719.78000000
#
#                Close         Volume     Close time Quote asset volume  \
# 0      3795.38000000   891.44907800  1546217999999   3383630.81245515
# ...

# %%
agg_trade_plot("BTCUSDT","1 days ago UTC")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-626502519ee2> in <module>
# ----> 1 agg_trade_plot("BTCUSDT","10 days ago UTC")
#
# c:\Users\James\OneDrive\Documents\git\stocks-model\get_data.py in agg_trade_plot(symbol, start_date)
#      69     column_names = ["Agg tradeID", "Price", "Quantity", "First tradeID", "Last tradeID", "Timestamp", "Buyer Maker", "Price Match"]
#      70     data = []
# ---> 71     for trade in list(client.aggregate_trade_iter(symbol, start_str=start_date)):
#      72         data.append(list(trade.values()))
#      73     df = pd.DataFrame(data, columns=column_names)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\binance\client.py in aggregate_trade_iter(self, symbol, start_str, last_id)
#     683             # data. That really simplifies this function's job. Binance is
#     684             # fucking awesome.
# ...
